# %% [markdown]
# # Geometric factor calculations using Monte Carlo simulation data
# By Andrei R. Hanu - <andrei.hanu@nasa.gov>
#
# ## Introduction
#
# The geometric factor ($\bf{G}$, units cm$^2$ sr) of a particle detector is analogous to the "collecting power" of an optical telescope and is a function of the surface area of the instrument and detection efficiency, which itself is a function of the charge, mass, and energy of the incident particles. If the detector's geometry factor is known, the spatial differential flux ($\bf{J}$, units particles cm$^{-2}$ sr$^{-1}$ sec$^{-1}$) incident on the detector can be calculated from the counting rate ($\bf{N_D}$, units particles $sec^{-1}$). So very simply, the geometric factor is defined as the counts received by a detector per unit time divided by the spatial differential flux around the instrument.
#
# $$ G = \frac{N_D}{J} $$
#
# ** Note: For radiation risk assesment calculations, the flux is typically measured in energy bins with units of particles cm$^{-2}$ sr$^{-1}$ sec$^{-1}$ MeV$^{-1}$ **
#
# Tradiationally, a detector's geometric factor has usually been estimated by approximation, however, only a few analytical solutions exist for simple source and detector geometries - see Sullivan (1971). For more complicated detector geometries, including electronic coincidence/anti-coincidence logic, an analytical solution might be difficult, or even impossible, to derive in the closed form. In such cases, the Monte Carlo technique is employed to compute the geometrical factor, see Crannell et al. (1971), by surrounded the detector geometry with a spherical source and assuming an isotropic radiation environment. Although, you can also apply this technique to anisotropic radiation environments.
#
# For isotropic radiation environments, the number of particles $\bf{N_R}$ traversing a sphere is determined by the integrating the spatial differential flux over the surface area of the sphere and solid angle.
#
# $$ N_R = \int_{\Omega}\int_{S} JdSd\Omega $$
#
# Where the differential surface area ($\bf{dS}$) and differential solid angle ($\bf{d\Omega}$) in spherical coordinates is:
#
# $$ dS = R^2 sin \theta d\theta d\phi $$
#
# $$ d\Omega = sin \theta d\theta d\phi $$
#
# Working through the integral, we see that the number of particles $\bf{N_R}$ traversing a sphere is:
#
# $$ N_R = 4 \pi^2 R^2 J $$
#
# And it depends on:
#
# - The radius (ie. bigger sphere == more particles crossing the sphere)
# - The spatial differential flux (ie. more flux == more particles crossing the sphere)
#
# Finally, by using Eq.1 and Eq. 5 the geometric factor for an isotropic radiation environments can be written as follows:
#
# $$ G = \frac{N_D}{N_R}4 \pi^2 R^2 $$
#
# Where:
#
# - $N_D$ is the number of particles interacting with the detector model
# - $N_R$ is the total number of simulated particles
# - $R$ is the radius of the spherical source encircling the detector model
#
# The associated standard deviation ($\bf{\sigma_G}$) is obtained from the binomial distribution and follows:
#
# $$ \sigma_G = 4\pi^2R^2 \sqrt{\left(1-\frac{N_D}{N_R}\right)\frac{N_D}{N_R^2}} $$
#
# ## Monte Carlo method
#
# To calculate the geometric factor of a detector using the Monte Carlo method, the following steps need to be taken:
#
# - The detector geometry, or a simplified model, should be implemented in your favourite Monte Carlo particle transport  code (Geant4, MCNP, FLUKA, EGS, etc)
#
# If an isotropic flux, typical of space-borne instruments, is assumed:
#
# - The detector geometry is enveloped by a spherical source such that the spectral, spatial, and angular distribution of primary particles can be specified
#
# - The primary particles must be uniformly distributed over the entire surface of spherical source
# - The angular distribution for the emission of primary particles must follow a cosine-law distribution
#
# ## References
#
# + Sullivan, J. D. "Geometric factor and directional response of single and multi-element particle telescopes." Nuclear Instruments and methods 95.1 (1971): 5-11.
#
# + Crannell, C. J., and J. F. Ormes. "Geometrical-factor determination using a monte carlo approach." Nuclear Instruments and Methods 94.1 (1971): 179-183.
#
# + Sanderson, T. R., and D. E. Page. "Geometrical aspects of the performance of cosmic ray detector telescopes in non-isotropic particle distributions." Nuclear Instruments and Methods 104.3 (1972): 493-504.

# %%
# Matplotlib - 2D plotting library
from matplotlib import pyplot as plt
from matplotlib import rcParams

# Show matplotlib figures inline the notebook
# %matplotlib inline

# Pandas - High-performance data analysis
import pandas

# Glob - Unix style pathname pattern expansion
# Used to aggregate folders and files into a single list so they can be iterated over
import glob

# Numpy - For handling of large, multi-dimensional arrays and matrices
import numpy as np

##########################################################################################
# Setting rcParams for publication quality graphs
fig_width_pt = 246.0                    # Get this from LaTeX using \showthe\columnwidth
inches_per_pt = 1.0/72.27               # Convert pt to inch
golden_mean = (np.sqrt(5)-1.0)/2.0      # Aesthetic ratio
fig_width = fig_width_pt*inches_per_pt  # Width in inches
fig_height = fig_width*golden_mean      # Height in inches
fig_size =  [fig_width, fig_height]
fig_size =  [7.3,4.2]
# fig_size =  [7.3*1.5,4.2*1.5]
# fig_size =  [7.3*2,4.2*2]
params = {'backend': 'pdf',
        'axes.labelsize': 10,
        'legend.fontsize':9,
        'xtick.labelsize': 10,
        'ytick.labelsize': 10,
        'xtick.major.size' : 6,
        'xtick.major.width' : 1,
        'xtick.minor.size' : 2.5,
        'xtick.minor.width' : 1,
        'ytick.major.size' : 6,
        'ytick.major.width' : 1,
        'ytick.minor.size' : 2.5,
        'ytick.minor.width' : 1,
        'font.family': 'sans-serif',
        'font.sans-serif': 'Avant Garde',
        'font.size': 10,
        'text.usetex': True,
        'figure.figsize': fig_size}

# Update rcParams
rcParams.update(params)

# %%
##########################################################################################
# Energy of incident (input) particles
InputEnergies = np.array([np.linspace(10,90, num=9, endpoint=True, dtype = int), 
                 np.linspace(100,900, num=9, endpoint=True, dtype = int), 
                 np.linspace(1000,9000, num=9, endpoint=True, dtype = int), 
                 np.linspace(10000,90000, num=9, endpoint=True, dtype = int)
                ]).flatten()

# Folder containing simulation data
DataFolder = '../Results/Electrons/4p16mm_scintillator/'

##########################################################################################
# Energy thresholds (in eV) for events that will be included in the analysis
Thr_TEPC = 100.
Thr_ACD = 100.

# %%
##########################################################################################
# Load the simulation data for each input energy
Data = []

for InputEnergy in InputEnergies:
    # Create data file template from current energy 
    DataFilename = 'e-_' + str(InputEnergy) + 'keV_ISO_nt_G4CNPTEPC_t*.csv'
    
    # Statistics variables for each input energy data
    nTotal = 0
    nCoinc = 0
    nAntiCoinc = 0
    nSubThr = 0
    
    # Print energy 
    print '\n------------------------------------------------------------'
    print 'Energy: \t\t', str(InputEnergy)

    ##########################################################################################
    # Process the simulation data files
    # Column 0 - Energy deposited in the TEPC sensitive volume [eV]
    # Column 1 - Track length of particles that entirely traverse the TEPC [mm]
    # Column 2 - Energy deposited in the plastic scintillator [eV]
    for dataFile in glob.glob(DataFolder + DataFilename):  
        # Readout CSV files
        dataFrame = pandas.read_csv(dataFile, header=-1, skiprows=6, usecols=[0,1,2]).values
        
        # Increment statistics
        nTotal += dataFrame[(dataFrame[:,0] > Thr_TEPC),0].size
        nCoinc += dataFrame[np.logical_and((dataFrame[:,2] > Thr_ACD),(dataFrame[:,0] > Thr_TEPC)),0].size
        nAntiCoinc += dataFrame[np.logical_and((dataFrame[:,2] <= Thr_ACD),(dataFrame[:,0] > Thr_TEPC)),0].size
        nSubThr += dataFrame[(dataFrame[:,0] <= Thr_TEPC),0].size
        
    # Add statistics to data list (Convert to numpy array later)
    Data.append([InputEnergy,nTotal,nCoinc,nAntiCoinc,nSubThr])
        
    # Print statistics
    print '------------------------------------------------------------'
    print 'Number of events above threshold: \t', nTotal
    print 'Number of events below threshold: \t', nSubThr
    print 'Number of coincidence events: \t\t', nCoinc
    print 'Number of anti-coincidence events: \t', nAntiCoinc
    print '------------------------------------------------------------'
    
# Convert statistics list to Numpy array
Data = np.asarray(Data)
# Out:
# ------------------------------------------------------------
# Energy: 		10
# ------------------------------------------------------------
# Number of events above threshold: 	1045978
# Number of events below threshold: 	23841
# Number of coincidence events: 		0
# Number of anti-coincidence events: 	1045978
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		20
# ------------------------------------------------------------
# Number of events above threshold: 	1016663
# Number of events below threshold: 	46690
# Number of coincidence events: 		0
# Number of anti-coincidence events: 	1016663
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		30
# ------------------------------------------------------------
# Number of events above threshold: 	986282
# Number of events below threshold: 	69276
# Number of coincidence events: 		1
# Number of anti-coincidence events: 	986281
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		40
# ------------------------------------------------------------
# Number of events above threshold: 	957306
# Number of events below threshold: 	94158
# Number of coincidence events: 		3
# Number of anti-coincidence events: 	957303
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		50
# ------------------------------------------------------------
# Number of events above threshold: 	927526
# Number of events below threshold: 	117780
# Number of coincidence events: 		14
# Number of anti-coincidence events: 	927512
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		60
# ------------------------------------------------------------
# Number of events above threshold: 	896308
# Number of events below threshold: 	141267
# Number of coincidence events: 		18
# Number of anti-coincidence events: 	896290
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		70
# ------------------------------------------------------------
# Number of events above threshold: 	868832
# Number of events below threshold: 	165687
# Number of coincidence events: 		32
# Number of anti-coincidence events: 	868800
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		80
# ------------------------------------------------------------
# Number of events above threshold: 	839686
# Number of events below threshold: 	189403
# Number of coincidence events: 		23
# Number of anti-coincidence events: 	839663
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		90
# ------------------------------------------------------------
# Number of events above threshold: 	812573
# Number of events below threshold: 	210293
# Number of coincidence events: 		40
# Number of anti-coincidence events: 	812533
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		100
# ------------------------------------------------------------
# Number of events above threshold: 	1082478
# Number of events below threshold: 	319188
# Number of coincidence events: 		58
# Number of anti-coincidence events: 	1082420
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		200
# ------------------------------------------------------------
# Number of events above threshold: 	610008
# Number of events below threshold: 	374101
# Number of coincidence events: 		102
# Number of anti-coincidence events: 	609906
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		300
# ------------------------------------------------------------
# Number of events above threshold: 	527704
# Number of events below threshold: 	436353
# Number of coincidence events: 		215
# Number of anti-coincidence events: 	527489
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		400
# ------------------------------------------------------------
# Number of events above threshold: 	480799
# Number of events below threshold: 	470026
# Number of coincidence events: 		289
# Number of anti-coincidence events: 	480510
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		500
# ------------------------------------------------------------
# Number of events above threshold: 	457250
# Number of events below threshold: 	491562
# Number of coincidence events: 		430
# Number of anti-coincidence events: 	456820
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		600
# ------------------------------------------------------------
# Number of events above threshold: 	441495
# Number of events below threshold: 	505815
# Number of coincidence events: 		547
# Number of anti-coincidence events: 	440948
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		700
# ------------------------------------------------------------
# Number of events above threshold: 	431020
# Number of events below threshold: 	518519
# Number of coincidence events: 		600
# Number of anti-coincidence events: 	430420
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		800
# ------------------------------------------------------------
# Number of events above threshold: 	426226
# Number of events below threshold: 	526408
# Number of coincidence events: 		741
# Number of anti-coincidence events: 	425485
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		900
# ------------------------------------------------------------
# Number of events above threshold: 	423738
# Number of events below threshold: 	535139
# Number of coincidence events: 		971
# Number of anti-coincidence events: 	422767
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		1000
# ------------------------------------------------------------
# Number of events above threshold: 	423487
# Number of events below threshold: 	540815
# Number of coincidence events: 		1078
# Number of anti-coincidence events: 	422409
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		2000
# ------------------------------------------------------------
# Number of events above threshold: 	501617
# Number of events below threshold: 	607506
# Number of coincidence events: 		121841
# Number of anti-coincidence events: 	379776
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		3000
# ------------------------------------------------------------
# Number of events above threshold: 	590377
# Number of events below threshold: 	654804
# Number of coincidence events: 		384661
# Number of anti-coincidence events: 	205716
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		4000
# ------------------------------------------------------------
# Number of events above threshold: 	1408931
# Number of events below threshold: 	1016990
# Number of coincidence events: 		1303304
# Number of anti-coincidence events: 	105627
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		5000
# ------------------------------------------------------------
# Number of events above threshold: 	2196989
# Number of events below threshold: 	1415735
# Number of coincidence events: 		2140378
# Number of anti-coincidence events: 	56611
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		6000
# ------------------------------------------------------------
# Number of events above threshold: 	2625041
# Number of events below threshold: 	1634115
# Number of coincidence events: 		2593708
# Number of anti-coincidence events: 	31333
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		7000
# ------------------------------------------------------------
# Number of events above threshold: 	2817785
# Number of events below threshold: 	1730641
# Number of coincidence events: 		2800419
# Number of anti-coincidence events: 	17366
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		8000
# ------------------------------------------------------------
# Number of events above threshold: 	2898328
# Number of events below threshold: 	1759050
# Number of coincidence events: 		2888775
# Number of anti-coincidence events: 	9553
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		9000
# ------------------------------------------------------------
# Number of events above threshold: 	2925011
# Number of events below threshold: 	1750919
# Number of coincidence events: 		2919647
# Number of anti-coincidence events: 	5364
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		10000
# ------------------------------------------------------------
# Number of events above threshold: 	2930654
# Number of events below threshold: 	1726767
# Number of coincidence events: 		2927384
# Number of anti-coincidence events: 	3270
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		20000
# ------------------------------------------------------------
# Number of events above threshold: 	3005992
# Number of events below threshold: 	1524274
# Number of coincidence events: 		3005270
# Number of anti-coincidence events: 	722
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		30000
# ------------------------------------------------------------
# Number of events above threshold: 	3087766
# Number of events below threshold: 	1438188
# Number of coincidence events: 		3087320
# Number of anti-coincidence events: 	446
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		40000
# ------------------------------------------------------------
# Number of events above threshold: 	3151513
# Number of events below threshold: 	1383736
# Number of coincidence events: 		3151226
# Number of anti-coincidence events: 	287
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		50000
# ------------------------------------------------------------
# Number of events above threshold: 	3198257
# Number of events below threshold: 	1344811
# Number of coincidence events: 		3198035
# Number of anti-coincidence events: 	222
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		60000
# ------------------------------------------------------------
# Number of events above threshold: 	3231681
# Number of events below threshold: 	1313882
# Number of coincidence events: 		3231493
# Number of anti-coincidence events: 	188
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		70000
# ------------------------------------------------------------
# Number of events above threshold: 	3258269
# Number of events below threshold: 	1287898
# Number of coincidence events: 		3258133
# Number of anti-coincidence events: 	136
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		80000
# ------------------------------------------------------------
# Number of events above threshold: 	3281582
# Number of events below threshold: 	1270950
# Number of coincidence events: 		3281462
# Number of anti-coincidence events: 	120
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Energy: 		90000
# ------------------------------------------------------------
# Number of events above threshold: 	3303473
# Number of events below threshold: 	1254530
# Number of coincidence events: 		3303371
# Number of anti-coincidence events: 	102
# ------------------------------------------------------------

# %%
##########################################################################################
# Calculate the geometry factor (G) assuming an isotropic radiation environment.
# The detector is centered on, and encircled by, a spherical source of radius (R) and
# with N_R simulated particles distributed uniformly along the inner surface.

# Source information (Get this from the Geant4 simulation!!)
N_R = 10000000.
R = 7.75

# Calculate the geometry factors
G_Total = Data[:,1]/N_R*4*(np.pi**2)*(R**2)
G_Coinc = Data[:,2]/N_R*4*(np.pi**2)*(R**2)
G_AntiCoinc = Data[:,3]/N_R*4*(np.pi**2)*(R**2)

# Calculate the errors for geometry factors 
err_G_Total = 4*(np.pi**2)*(R**2)*np.sqrt((1-Data[:,1]/N_R)*Data[:,1]/N_R**2)
err_G_Coinc = 4*(np.pi**2)*(R**2)*np.sqrt((1-Data[:,2]/N_R)*Data[:,2]/N_R**2)
err_G_AntiCoinc = 4*(np.pi**2)*(R**2)*np.sqrt((1-Data[:,3]/N_R)*Data[:,3]/N_R**2)

# %%
##########################################################################################
# Plot the Geometry Factor over a range of particle energies
fig_G, ax_G = plt.subplots(1,1)

plt.loglog(Data[:,0], G_Total, 'k-', linewidth=0.75, label="Total")
plt.loglog(Data[:,0], G_Coinc, 'k--', linewidth=0.75, label="Coincidence")
plt.loglog(Data[:,0], G_AntiCoinc, 'k:', linewidth=0.75, label="Anti-Coincidence")

# Figure Properties
ax_G.set_ylabel(r'Geometric Factor (cm$^2$ sr)')  
ax_G.set_xlabel('Incident Electron Energy (keV)') 
ax_G.set_ylim(1., 1000.)
ax_G.set_xlim(10., 100000.)
ax_G.legend(loc=3)

# Tight Layout
plt.tight_layout()

# Save the figure 
file_G = 'Geometric_Factor_Electrons.pdf'
plt.savefig(DataFolder + file_G, bbox_inches="tight")
print 'Plot saved to: ' + (DataFolder+file_G)

# Show the figure
plt.show(fig_G)
# Out:
# Plot saved to: ../Results/Electrons/4p16mm_scintillator/Geometric_Factor_Electrons.pdf
